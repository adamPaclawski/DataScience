# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mordred import Calculator, descriptors
from rdkit import Chem

path = '/home/adam/Pobrane/PythonML/DataScience/DataScience/simple_solubility_database.csv'
df = pd.read_csv(path, sep=",")

print(df)
# Out:
#                                                    Name    MolWt  MolLogP  \
# 0            N,N,N-trimethyloctadecan-1-aminium bromide  392.510  3.95810
# 1                              Benzo[cd]indol-2(1H)-one  169.183  2.40550
# 2                                  4-chlorobenzaldehyde  140.569  2.15250
# 3     zinc bis[2-hydroxy-3,5-bis(1-phenylethyl)benzo...  756.226  8.11610
# 4     4-({4-[bis(oxiran-2-ylmethyl)amino]phenyl}meth...  422.525  2.48540
# ...                                                 ...      ...      ...
# 9977                                         tetracaine  264.369  2.61700
# 9978                                       tetracycline  444.440 -0.21440
# 9979                                             thymol  150.221  2.82402
# 9980                                          verapamil  454.611  5.09308
# 9981                                           warfarin  308.333  3.60960
#
#          MolMR  HeavyAtomCount  NumHAcceptors  NumHDonors  NumHeteroatoms  \
# ...

# %%
df.head()
# Out:
#                                                 Name    MolWt  MolLogP  \
# 0         N,N,N-trimethyloctadecan-1-aminium bromide  392.510   3.9581
# 1                           Benzo[cd]indol-2(1H)-one  169.183   2.4055
# 2                               4-chlorobenzaldehyde  140.569   2.1525
# 3  zinc bis[2-hydroxy-3,5-bis(1-phenylethyl)benzo...  756.226   8.1161
# 4  4-({4-[bis(oxiran-2-ylmethyl)amino]phenyl}meth...  422.525   2.4854
#
#       MolMR  HeavyAtomCount  NumHAcceptors  NumHDonors  NumHeteroatoms  \
# 0  102.4454            23.0            0.0         0.0             2.0
# 1   51.9012            13.0            1.0         1.0             2.0
# 2   36.8395             9.0            1.0         0.0             2.0
# 3  200.7106            53.0            6.0         2.0             7.0
# 4  119.0760            31.0            6.0         0.0             6.0
#
#    NumRotatableBonds  NumValenceElectrons  NumAromaticRings  \
# ...

# %%
print(__doc__)


# Code source: Jaques Grobler
# License: BSD 3 clause


import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# Load the diabetes dataset
diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True)

# Use only one feature
diabetes_X = diabetes_X[:, np.newaxis, 2]

# Split the data into training/testing sets
diabetes_X_train = diabetes_X[:-20]
diabetes_X_test = diabetes_X[-20:]

# Split the targets into training/testing sets
diabetes_y_train = diabetes_y[:-20]
diabetes_y_test = diabetes_y[-20:]

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(diabetes_X_train, diabetes_y_train)

# Make predictions using the testing set
diabetes_y_pred = regr.predict(diabetes_X_test)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(diabetes_y_test, diabetes_y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(diabetes_y_test, diabetes_y_pred))

# Plot outputs
plt.scatter(diabetes_X_test, diabetes_y_test,  color='black')
plt.plot(diabetes_X_test, diabetes_y_pred, color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# Automatically created module for IPython interactive environment
# Coefficients:
#  [938.23786125]
# Mean squared error: 2548.07
# Coefficient of determination: 0.47

# %%
df=diabetes_X
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-2d20f0ea383b> in <module>
# ----> 1 diabetes_X.size()
#
# TypeError: 'int' object is not callable

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

path = '/home/adam/Pobrane/PythonML/DataScience/DataScience/simple_solubility_database.csv'
df = pd.read_csv(path, sep=",")

# %%
df.shape
# Out:
# (9982, 18)

# %%
df.describe()
# Out:
#              MolWt      MolLogP        MolMR  HeavyAtomCount  NumHAcceptors  \
# count  9982.000000  9982.000000  9982.000000     9982.000000    9982.000000
# mean    266.665946     1.979167    66.794594       17.374674       3.486776
# std     184.179024     3.517738    46.523021       12.241536       3.498203
# min       9.012000   -40.873200     0.000000        1.000000       0.000000
# 25%     162.276000     0.619750    40.602475       11.000000       2.000000
# 50%     228.682000     1.949220    58.633400       15.000000       3.000000
# 75%     320.436000     3.419030    81.938000       21.000000       4.000000
# max    5299.456000    68.541140  1419.351700      388.000000      86.000000
#
#         NumHDonors  NumHeteroatoms  NumRotatableBonds  NumValenceElectrons  \
# count  9982.000000     9982.000000        9982.000000          9982.000000
# mean      1.108595        5.196955           4.073031            94.243438
# ...

# %%
df.plot(x='MolMR', y='solubility_mg_L', style='o')  
plt.title('MowlWt vs solubility_mg_L')  
plt.xlabel('MowlWt')  
plt.ylabel('solubility_mg_L')  
plt.show()

# %%
X = df['MolLogP'].values.reshape(-1,1)
y = df['solubility_mg_L'].values.reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
regressor = LinearRegression()  
regressor.fit(X_train, y_train) #training the algorithm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#To retrieve the intercept:
print(regressor.intercept_)#For retrieving the slope:
print(regressor.coef_)
# Out:
# [151109.19148619]
# [[-25241.16900087]]

# %%
y_pred = regressor.predict(X_test)

# %%
df2 = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
df2
# Out:
#            Actual      Predicted
# 0       41.998961   73192.226897
# 1        1.710938   91426.447384
# 2        8.449745   68345.922449
# 3       79.000000  135179.489730
# 4        1.000000   58739.133528
# ...           ...            ...
# 1992     7.639961   94008.114149
# 1993    27.001357  112916.778671
# 1994  6530.000000   96431.771197
# 1995  1800.000000  123602.879979
# 1996   173.799274   52755.966828
#
# [1997 rows x 2 columns]

# %%
plt.scatter(X_test, y_test,  color='gray')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.show()

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 150188.30975248883
# Mean Squared Error: 110092755179.38594
# Root Mean Squared Error: 331802.28326427465

# %%
X = df['MolLogP'].values.reshape(-1,1)
y = df['solubility_mg_L'].values.reshape(-1,1)
y2=np.log(y)

# %%
y2
# Out:
# array([[4.55387689],
#        [4.54435805],
#        [6.84054653],
#        ...,
#        [6.87720147],
#        [3.86290872],
#        [1.6325789 ]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y2, test_size=0.2, random_state=0)

# %%
regressor = LinearRegression()  
regressor.fit(X_train, y_train) #training the algorithm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#To retrieve the intercept:
print(regressor.intercept_)#For retrieving the slope:
print(regressor.coef_)
# Out:
# [7.4346602]
# [[-0.88513957]]

# %%
y_pred = regressor.predict(X_test)
df2 = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
df2
plt.scatter(X_test, y_test,  color='gray')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.show()

# %%
df2
# Out:
#             Actual  Predicted
# 0     3.737645e+00   4.702323
# 1     5.370416e-01   5.341748
# 2     2.134136e+00   4.532376
# 3     4.369448e+00   6.876049
# 4     9.956835e-11   4.195492
# ...            ...        ...
# 1992  2.033393e+00   5.432280
# 1993  3.295887e+00   6.095356
# 1994  8.784162e+00   5.517271
# 1995  7.495542e+00   6.470088
# 1996  5.157901e+00   3.985678
#
# [1997 rows x 2 columns]

# %% [markdown]
# Multiple linear regression - Rige Regression

# %%
from sklearn import linear_model
reg = linear_model.Ridge(alpha=.5)
reg.fit(X, y2)
# Out:
# Ridge(alpha=0.5, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
print(reg.coef_, reg.intercept_)
y_pred = regressor.predict(X)
# Out:
# [[-0.89758614]] [7.46083921]

# %%
df2 = pd.DataFrame({'Actual': y2.flatten(), 'Predicted': y_pred.flatten()})
df2
# Out:
#         Actual  Predicted
# 0     4.553877   3.931189
# 1     4.544358   5.305457
# 2     6.840547   5.529397
# 3     4.499810   0.250779
# 4     2.219203   5.234734
# ...        ...        ...
# 9977  5.554320   5.118250
# 9978  6.257996   7.624434
# 9979  6.877201   4.935008
# 9980  3.862909   2.926574
# 9981  1.632579   4.239660
#
# [9982 rows x 2 columns]

# %%
plt.scatter(y2, y_pred,  color='gray')
#plt.plot(y2, y_pred, color='red', linewidth=2)
plt.show()

# %% [markdown]
# Multiple linear regression

# %%
X=df[list(df)[1:17]]
from sklearn import *
reg = linear_model.Ridge(alpha=.99)
reg.fit(X, y2)
print(reg.coef_, reg.intercept_)
y_pred = reg.predict(X)
# Out:
# [[-0.00864463 -1.05038813  0.05865683 -0.08977663  0.30391435  0.27489482
#   -0.11418231 -0.04060226  0.049767   -0.29868222 -0.1662212  -0.11017847
#   -0.40886069 -0.00824599 -0.03652306  0.0808165 ]] [7.75087573]

# %%
plt.scatter(y2, y_pred,  color='gray')
#plt.plot(y2, y_pred, color='red', linewidth=2)
plt.show()

# %%
df2 = pd.DataFrame({'Actual': y2.flatten(), 'Predicted': y_pred.flatten()})
df2
# Out:
#         Actual  Predicted
# 0     4.553877   4.503182
# 1     4.544358   4.363600
# 2     6.840547   5.218930
# 3     4.499810  -3.055353
# 4     2.219203   3.276416
# ...        ...        ...
# 9977  5.554320   6.542186
# 9978  6.257996   9.048941
# 9979  6.877201   5.564904
# 9980  3.862909   3.768529
# 9981  1.632579   3.681505
#
# [9982 rows x 2 columns]

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_pred, y2))  
print('Mean Squared Error:', metrics.mean_squared_error(y_pred, y2))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_pred, y2)))
# Out:
# Mean Absolute Error: 2.833524741128421
# Mean Squared Error: 14.602781603999114
# Root Mean Squared Error: 3.821358607092393

# %%
df['LogS'] = y2

# %%
df["LogS"].median()
# Out:
# 6.278985215367567

# %%
metrics.r2_score(y2, y_pred)
# Out:
# 0.4601473949786955

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()
reg.fit(X, y2)
print(reg.coef_, reg.intercept_)
y_pred = reg.predict(X)
df2 = pd.DataFrame({'Actual': y2.flatten(), 'Predicted': y_pred.flatten()})
df2
print('Mean Absolute Error:', metrics.mean_absolute_error(y_pred, y2))  
print('Mean Squared Error:', metrics.mean_squared_error(y_pred, y2))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_pred, y2)))
# Out:
# [[-0.00864368 -1.05043783  0.05866363 -0.08971013  0.30392934  0.27491859
#   -0.1141982  -0.04062166  0.0497588  -0.2987574  -0.16625733 -0.11018052
#   -0.40893792 -0.00824857 -0.03652793  0.08082603]] [7.75084397]
# Mean Absolute Error: 2.83352203179939
# Mean Squared Error: 14.602781600933898
# Root Mean Squared Error: 3.821358606691329

# %%
from sklearn import linear_model
reg = linear_model.Lasso()
reg.fit(X, y2)
print(reg.coef_, reg.intercept_)
y_pred = reg.predict(X)
df2 = pd.DataFrame({'Actual': y2.flatten(), 'Predicted': y_pred.flatten()})
df2
print('Mean Absolute Error:', metrics.mean_absolute_error(y_pred, y2))  
print('Mean Squared Error:', metrics.mean_squared_error(y_pred, y2))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_pred, y2)))
# Out:
# [-0.01477821 -0.64079211 -0.         -0.          0.          0.
#  -0.          0.06755142  0.03191338 -0.         -0.         -0.
#  -0.          0.01824066 -0.01526288  0.        ] [8.13371502]
# Mean Absolute Error: 2.97178566898689
# Mean Squared Error: 15.558903939655783
# Root Mean Squared Error: 3.9444776510528974

# %%
#Rozwinięcie wilomianowe problemu
from sklearn.linear_model import Perceptron
from sklearn.preprocessing import PolynomialFeatures
import numpy as np
X2=PolynomialFeatures(interaction_only=True).fit_transform(X)
#X=PolynomialFeatures(interaction_only=True).fit_transform(X)

# %%
reg = linear_model.Lasso()
reg.fit(X2, y2)
print(reg.coef_, reg.intercept_)
y_pred = reg.predict(X2)
df2 = pd.DataFrame({'Actual': y2.flatten(), 'Predicted': y_pred.flatten()})
df2
print('Mean Absolute Error:', metrics.mean_absolute_error(y_pred, y2))  
print('Mean Squared Error:', metrics.mean_squared_error(y_pred, y2))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_pred, y2)))
# Out:
# [ 0.00000000e+00  0.00000000e+00 -1.93873880e-02 ...  1.28554275e-07
#  -4.36537546e-08 -7.92939364e-06] [11.08547974]
# Mean Absolute Error: 2.059338968343857
# Mean Squared Error: 8.164792141111807
# Root Mean Squared Error: 2.8574100407732534
# /home/adam/anaconda3/envs/ML/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 43219.689261190724, tolerance: 27.000882206610218
#   positive)

# %%
reg = linear_model.LinearRegression()
reg.fit(X2, y2)
print(reg.coef_, reg.intercept_)
y_pred = reg.predict(X2)
df2 = pd.DataFrame({'Actual': y2.flatten(), 'Predicted': y_pred.flatten()})
df2
print('Mean Absolute Error:', metrics.mean_absolute_error(y_pred, y2))  
print('Mean Squared Error:', metrics.mean_squared_error(y_pred, y2))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_pred, y2)))
# Out:
# [[-1.35162143e+00 -5.62724087e+00  9.80825784e-03 ... -9.17287765e-05
#   -7.89244199e-04 -7.46565034e-03]] [5.27474503]
# Mean Absolute Error: 1.036083293306847
# Mean Squared Error: 2.2514454554898418
# Root Mean Squared Error: 1.500481741138439

# %% [markdown]
# BiggerDataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mordred import Calculator, descriptors
from rdkit import Chem

path = './simple_solubility_database.csv'
df = pd.read_csv(path, sep=",")

#print(df)
#Select the row
df.iloc[0,:]
#Select column
df.iloc[:,0]
c

# %%
df.iloc[1,1]=np.nan

# %%
df.describe()
# Out:
#            MolLogP        MolMR  HeavyAtomCount  NumHAcceptors   NumHDonors  \
# count  9982.000000  9982.000000     9982.000000    9982.000000  9982.000000
# mean      1.979167    66.794594       17.374674       3.486776     1.108595
# std       3.517738    46.523021       12.241536       3.498203     1.488973
# min     -40.873200     0.000000        1.000000       0.000000     0.000000
# 25%       0.619750    40.602475       11.000000       2.000000     0.000000
# 50%       1.949220    58.633400       15.000000       3.000000     1.000000
# 75%       3.419030    81.938000       21.000000       4.000000     2.000000
# max      68.541140  1419.351700      388.000000      86.000000    26.000000
#
#        NumHeteroatoms  NumRotatableBonds  NumValenceElectrons  \
# count     9982.000000        9982.000000          9982.000000
# mean         5.196955           4.073031            94.243438
# std          4.736275           5.646925            64.748563
# ...

# %%
df.isna().sum()
# Out:
# Name                   0
# MolWt                  1
# MolLogP                0
# MolMR                  0
# HeavyAtomCount         0
# NumHAcceptors          0
# NumHDonors             0
# NumHeteroatoms         0
# NumRotatableBonds      0
# NumValenceElectrons    0
# NumAromaticRings       0
# NumSaturatedRings      0
# NumAliphaticRings      0
# RingCount              0
# TPSA                   0
# LabuteASA              0
# BalabanJ               0
# solubility_mg_L        0
# Index                  0
# dtype: int64

# %%
df_clean=df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

# %%
na_data=df.iloc[30,:]

# %%
na_data[2]=np.nan
df=df.append(na_data, ignore_index=True)
#df.reset_index()
# Out:
# /home/adam/anaconda3/envs/ML/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.isna().sum()
# Out:
# Name                   0
# MolWt                  1
# MolLogP                1
# MolMR                  0
# HeavyAtomCount         0
# NumHAcceptors          0
# NumHDonors             0
# NumHeteroatoms         0
# NumRotatableBonds      0
# NumValenceElectrons    0
# NumAromaticRings       0
# NumSaturatedRings      0
# NumAliphaticRings      0
# RingCount              0
# TPSA                   0
# LabuteASA              0
# BalabanJ               0
# solubility_mg_L        0
# dtype: int64

# %%
#Remove missing values
df.shape
df.drop("Index", axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Name', 'MolWt', 'MolLogP', 'MolMR', 'HeavyAtomCount', 'NumHAcceptors',
#        'NumHDonors', 'NumHeteroatoms', 'NumRotatableBonds',
#        'NumValenceElectrons', 'NumAromaticRings', 'NumSaturatedRings',
#        'NumAliphaticRings', 'RingCount', 'TPSA', 'LabuteASA', 'BalabanJ',
#        'solubility_mg_L'],
#       dtype='object')

# %%
df1 = df[df.isna().any(axis=1)]
df1.reset_index()
#df.drop("index", axis=1, inplace=True)
df1.columns
# Out:
# Index(['Name', 'MolWt', 'MolLogP', 'MolMR', 'HeavyAtomCount', 'NumHAcceptors',
#        'NumHDonors', 'NumHeteroatoms', 'NumRotatableBonds',
#        'NumValenceElectrons', 'NumAromaticRings', 'NumSaturatedRings',
#        'NumAliphaticRings', 'RingCount', 'TPSA', 'LabuteASA', 'BalabanJ',
#        'solubility_mg_L'],
#       dtype='object')

# %%
df.applymap(np.isreal)
# Out:
#        Name  MolWt  MolLogP  MolMR  HeavyAtomCount  NumHAcceptors  NumHDonors  \
# 0     False   True     True   True            True           True        True
# 1     False   True     True   True            True           True        True
# 2     False   True     True   True            True           True        True
# 3     False   True     True   True            True           True        True
# 4     False   True     True   True            True           True        True
# ...     ...    ...      ...    ...             ...            ...         ...
# 9978  False   True     True   True            True           True        True
# 9979  False   True     True   True            True           True        True
# 9980  False   True     True   True            True           True        True
# 9981  False   True     True   True            True           True        True
# 9982  False   True     True   True            True           True        True
#
# ...

# %%
for i in range(1:900):
# Out:
# RangeIndex(start=0, stop=9983, step=1)

# %%
df.plot(x="MolWt", y="solubility_mg_L", kind="scatter")

# %%
x=df["solubility_mg_L"]/df["MolWt"]

# %%
df.MolWt.isna().sum()
# Out:
# 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mordred import Calculator, descriptors
from rdkit import Chem

path = '/home/adam/Pobrane/PythonML/DataScience/DataScience/simple_solubility_database.csv'
df = pd.read_csv(path, sep=",")

print(df)
# Out:
#                                                    Name    MolWt  MolLogP  \
# 0            N,N,N-trimethyloctadecan-1-aminium bromide  392.510  3.95810
# 1                              Benzo[cd]indol-2(1H)-one  169.183  2.40550
# 2                                  4-chlorobenzaldehyde  140.569  2.15250
# 3     zinc bis[2-hydroxy-3,5-bis(1-phenylethyl)benzo...  756.226  8.11610
# 4     4-({4-[bis(oxiran-2-ylmethyl)amino]phenyl}meth...  422.525  2.48540
# ...                                                 ...      ...      ...
# 9977                                         tetracaine  264.369  2.61700
# 9978                                       tetracycline  444.440 -0.21440
# 9979                                             thymol  150.221  2.82402
# 9980                                          verapamil  454.611  5.09308
# 9981                                           warfarin  308.333  3.60960
#
#          MolMR  HeavyAtomCount  NumHAcceptors  NumHDonors  NumHeteroatoms  \
# ...

# %%
import random as rd
for i in range(0, 100):
    r=rd.sample(range(0, df.shape[0]), 1)
    new=df.iloc[r,:]
    new.reset_index
    new.iloc[0,0]="compound"+str(i)
    new.iloc[0,rd.sample(range(1, df.shape[1]), 1)]=np.nan
    df=df.append(new, ignore_index=True)
    print(new)
    
#df.insert(5, 'classificcation', value="unknown")
# Out:
# /home/adam/anaconda3/envs/ML/lib/python3.7/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# /home/adam/anaconda3/envs/ML/lib/python3.7/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# /home/adam/anaconda3/envs/ML/lib/python3.7/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df.to_csv("raw_data.csv", index=False)

# %%
df[df.isna().any(axis=1)]
# Out:
#              Name    MolWt  MolLogP    MolMR  HeavyAtomCount  NumHAcceptors  \
# 9982    compound0  221.322   1.1866  55.9083            14.0            3.0
# 9983    compound1  214.294   0.3715  56.9234            14.0            6.0
# 9984    compound2  139.110   1.3004  34.7612            10.0            NaN
# 9985    compound3  228.288   2.2292  60.8740            16.0            4.0
# 9986    compound4  110.971   1.9777  25.7130             5.0            0.0
# ...           ...      ...      ...      ...             ...            ...
# 10077  compound95   82.146   2.1166  27.6080             6.0            0.0
# 10078  compound96  135.210      NaN  43.8330            10.0            1.0
# 10079  compound97  147.004   2.9934  36.4620             8.0            0.0
# 10080  compound98  267.737   3.1408  68.7025            17.0            2.0
# 10081  compound99  250.081   1.6534  57.4420            15.0            3.0
#
# ...

# %%
df1
# Out:
#               Name    MolWt  MolLogP    MolMR  HeavyAtomCount  NumHAcceptors  \
# 9982     compound0  128.087 -1.25750  26.2984             9.0            3.0
# 9983     compound1      NaN  0.89500  66.2089            18.0            4.0
# 9984     compound2  222.372  3.94200  70.2468            16.0            1.0
# 9985     compound3  250.258  0.66640  63.6957            18.0            6.0
# 9986     compound4  250.283      NaN  63.6949            17.0            5.0
# ...            ...      ...      ...      ...             ...            ...
# 10977  compound995  304.348  4.74860      NaN            19.0            5.0
# 10978  compound996  199.257  2.83704  61.2307            15.0            3.0
# 10979  compound997  162.279  1.75530  45.8614             9.0            2.0
# 10980  compound998  192.045  2.29854  46.5567            11.0            1.0
# 10981  compound999  263.425  4.04880  82.8978            19.0            2.0
#
# ...

# %%
df.insert(2, 'Classicication', value="unknown")

# %%
df.drop("Classicication", axis=1, inplace=True)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                                                     Name    MolWt  MolLogP  \
# 0             N,N,N-trimethyloctadecan-1-aminium bromide  392.510  3.95810
# 1                               Benzo[cd]indol-2(1H)-one  169.183  2.40550
# 2                                   4-chlorobenzaldehyde  140.569  2.15250
# 3      zinc bis[2-hydroxy-3,5-bis(1-phenylethyl)benzo...  756.226  8.11610
# 4      4-({4-[bis(oxiran-2-ylmethyl)amino]phenyl}meth...  422.525  2.48540
# ...                                                  ...      ...      ...
# 10977                                        compound995  304.348  4.74860
# 10978                                        compound996  199.257  2.83704
# 10979                                        compound997  162.279  1.75530
# 10980                                        compound998  192.045  2.29854
# 10981                                        compound999  263.425  4.04880
#
# ...

# %%
import numpy as np
import pandas as pd
from sklearn import *
import matplotlib.pyplot as plt

path = './raw_simple_solubility_database.csv'
raw_df = pd.read_csv(path, sep=",")

print(raw_df)
# Out:
#                                                     Name    MolWt  MolLogP  \
# 0             N,N,N-trimethyloctadecan-1-aminium bromide  392.510   3.9581
# 1                               Benzo[cd]indol-2(1H)-one  169.183   2.4055
# 2                                   4-chlorobenzaldehyde  140.569   2.1525
# 3      zinc bis[2-hydroxy-3,5-bis(1-phenylethyl)benzo...  756.226   8.1161
# 4      4-({4-[bis(oxiran-2-ylmethyl)amino]phenyl}meth...  422.525   2.4854
# ...                                                  ...      ...      ...
# 10077                                         compound95   82.146   2.1166
# 10078                                         compound96  135.210      NaN
# 10079                                         compound97  147.004   2.9934
# 10080                                         compound98  267.737   3.1408
# 10081                                         compound99  250.081   1.6534
#
# ...

# %%
raw_df.describe
# Out:
# <bound method NDFrame.describe of                                                     Name    MolWt  MolLogP  \
# 0             N,N,N-trimethyloctadecan-1-aminium bromide  392.510   3.9581
# 1                               Benzo[cd]indol-2(1H)-one  169.183   2.4055
# 2                                   4-chlorobenzaldehyde  140.569   2.1525
# 3      zinc bis[2-hydroxy-3,5-bis(1-phenylethyl)benzo...  756.226   8.1161
# 4      4-({4-[bis(oxiran-2-ylmethyl)amino]phenyl}meth...  422.525   2.4854
# ...                                                  ...      ...      ...
# 10077                                         compound95   82.146   2.1166
# 10078                                         compound96  135.210      NaN
# 10079                                         compound97  147.004   2.9934
# 10080                                         compound98  267.737   3.1408
# 10081                                         compound99  250.081   1.6534
#
# ...

# %%
raw_df.isna().sum()
# Out:
# Name                    0
# MolWt                   4
# MolLogP                12
# MolMR                   7
# HeavyAtomCount          4
# NumHAcceptors           6
# NumHDonors              3
# NumHeteroatoms          9
# NumRotatableBonds       4
# NumValenceElectrons     5
# NumAromaticRings       11
# NumSaturatedRings      10
# NumAliphaticRings       3
# RingCount               2
# TPSA                   10
# LabuteASA               5
# BalabanJ                2
# solubility_mg_L         4
# dtype: int64

# %%
raw_df[raw_df.isna().any(axis=1)]
# Out:
#              Name    MolWt  MolLogP    MolMR  HeavyAtomCount  NumHAcceptors  \
# 9982    compound0  221.322   1.1866  55.9083            14.0            3.0
# 9983    compound1  214.294   0.3715  56.9234            14.0            6.0
# 9984    compound2  139.110   1.3004  34.7612            10.0            NaN
# 9985    compound3  228.288   2.2292  60.8740            16.0            4.0
# 9986    compound4  110.971   1.9777  25.7130             5.0            0.0
# ...           ...      ...      ...      ...             ...            ...
# 10077  compound95   82.146   2.1166  27.6080             6.0            0.0
# 10078  compound96  135.210      NaN  43.8330            10.0            1.0
# 10079  compound97  147.004   2.9934  36.4620             8.0            0.0
# 10080  compound98  267.737   3.1408  68.7025            17.0            2.0
# 10081  compound99  250.081   1.6534  57.4420            15.0            3.0
#
# ...

# %%
df=raw_df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

# %%
df.isna().sum()
# Out:
# Name                   0
# MolWt                  0
# MolLogP                0
# MolMR                  0
# HeavyAtomCount         0
# NumHAcceptors          0
# NumHDonors             0
# NumHeteroatoms         0
# NumRotatableBonds      0
# NumValenceElectrons    0
# NumAromaticRings       0
# NumSaturatedRings      0
# NumAliphaticRings      0
# RingCount              0
# TPSA                   0
# LabuteASA              0
# BalabanJ               0
# solubility_mg_L        0
# dtype: int64

# %%
df.describe()
# Out:
#              MolWt      MolLogP        MolMR  HeavyAtomCount  NumHAcceptors  \
# count  9982.000000  9982.000000  9982.000000     9982.000000    9982.000000
# mean    266.665946     1.979167    66.794594       17.374674       3.486776
# std     184.179024     3.517738    46.523021       12.241536       3.498203
# min       9.012000   -40.873200     0.000000        1.000000       0.000000
# 25%     162.276000     0.619750    40.602475       11.000000       2.000000
# 50%     228.682000     1.949220    58.633400       15.000000       3.000000
# 75%     320.436000     3.419030    81.938000       21.000000       4.000000
# max    5299.456000    68.541140  1419.351700      388.000000      86.000000
#
#         NumHDonors  NumHeteroatoms  NumRotatableBonds  NumValenceElectrons  \
# count  9982.000000     9982.000000        9982.000000          9982.000000
# mean      1.108595        5.196955           4.073031            94.243438
# ...

# %%
df.solubility_mg_L.describe()
# Out:
# count    9.982000e+03
# mean     1.003622e+05
# std      5.837046e+05
# min      4.400463e-08
# 25%      1.259900e+01
# 50%      5.332473e+02
# 75%      1.200120e+04
# max      3.770000e+07
# Name: solubility_mg_L, dtype: float64

# %%
logS=np.log10(df.solubility_mg_L/1000/df.MolWt)
logS.reset_index
df["logS"]=logS
df.describe()
# Out:
# /home/adam/anaconda3/envs/ML/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#              MolWt      MolLogP        MolMR  HeavyAtomCount  NumHAcceptors  \
# count  9982.000000  9982.000000  9982.000000     9982.000000    9982.000000
# mean    266.665946     1.979167    66.794594       17.374674       3.486776
# std     184.179024     3.517738    46.523021       12.241536       3.498203
# min       9.012000   -40.873200     0.000000        1.000000       0.000000
# 25%     162.276000     0.619750    40.602475       11.000000       2.000000
# ...

# %%
df.logS.plot(kind="hist")

# %%
X=df[df.columns[1:17]]

# %%
Y=df[df.columns[18]]

# %%
Y
# Out:
# 0      -3.616127
# 1      -3.254767
# 2      -2.177078
# 3      -3.924409
# 4      -4.662065
#           ...
# 9977   -3.010000
# 9978   -2.930000
# 9979   -2.190000
# 9980   -3.980000
# 9981   -4.780000
# Name: logS, Length: 9982, dtype: float64

# %%
X
# Out:
#         MolWt  MolLogP     MolMR  HeavyAtomCount  NumHAcceptors  NumHDonors  \
# 0     392.510  3.95810  102.4454            23.0            0.0         0.0
# 1     169.183  2.40550   51.9012            13.0            1.0         1.0
# 2     140.569  2.15250   36.8395             9.0            1.0         0.0
# 3     756.226  8.11610  200.7106            53.0            6.0         2.0
# 4     422.525  2.48540  119.0760            31.0            6.0         0.0
# ...       ...      ...       ...             ...            ...         ...
# 9977  264.369  2.61700   78.6762            19.0            4.0         1.0
# 9978  444.440 -0.21440  109.5409            32.0            9.0         6.0
# 9979  150.221  2.82402   46.9328            11.0            1.0         1.0
# 9980  454.611  5.09308  131.6560            33.0            6.0         0.0
# 9981  308.333  3.60960   87.7318            23.0            4.0         1.0
#
# ...

# %%
from sklearn import *

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred=reg.predict(X)
# The coefficients
print('Coefficients: \n', reg.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % metrics.mean_squared_error(Y, y_pred, squared=False))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % metrics.r2_score(Y, y_pred))
# Out:
# Coefficients:
#  [-0.00483823 -0.45543546  0.02279459 -0.03219148  0.14205969  0.12243226
#  -0.06330249 -0.02259244  0.02132051 -0.13315684 -0.06181049 -0.06412062
#  -0.19727746 -0.00361012 -0.01426212  0.04104454]
# Mean squared error: 1.70
# Coefficient of determination: 0.48

# %%
plt.plot(Y, y_pred, "bo")

# %%
reg = linear_model.RidgeCV(alphas=np.logspace(-6, 6, 13))
reg.fit(X,Y)
y_pred=reg.predict(X)
# The coefficients
print('Coefficients: \n', reg.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % metrics.mean_squared_error(Y, y_pred, squared=False))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % metrics.r2_score(Y, y_pred))
# Out:
# Coefficients:
#  [-0.00520799 -0.43483105  0.02011309 -0.05218099  0.13448129  0.11280035
#  -0.05558476 -0.0141174   0.02359289 -0.11009226 -0.05759943 -0.05543436
#  -0.16552662 -0.00254866 -0.01259601  0.03587396]
# Mean squared error: 1.71
# Coefficient of determination: 0.48

# %%
reg = linear_model.Lasso(alpha=0.01)
reg.fit(X,Y)
y_pred=reg.predict(X)
# The coefficients
print('Coefficients: \n', reg.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % metrics.mean_squared_error(Y, y_pred, squared=False))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % metrics.r2_score(Y, y_pred))
# Out:
# Coefficients:
#  [-0.00480143 -0.45269936  0.02300945 -0.0041612   0.12657381  0.11022931
#  -0.05255715 -0.01390826  0.0168151  -0.03477905 -0.          0.
#  -0.29062189 -0.0031253  -0.01592457  0.02670785]
# Mean squared error: 1.70
# Coefficient of determination: 0.48

# %%
reg = linear_model.BayesianRidge()
reg.fit(X,Y)
y_pred=reg.predict(X)
# The coefficients
print('Coefficients: \n', reg.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % metrics.mean_squared_error(Y, y_pred, squared=False))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % metrics.r2_score(Y, y_pred))
# Out:
# Coefficients:
#  [-0.00490091 -0.45247178  0.02239136 -0.03699932  0.14098262  0.12089155
#  -0.0621275  -0.02128623  0.02192969 -0.12882762 -0.06224912 -0.06249608
#  -0.19132371 -0.00344985 -0.01395757  0.04047951]
# Mean squared error: 1.70
# Coefficient of determination: 0.48

# %%
reg.fit(X[X.columns[9:15]],Y)
y_pred=reg.predict(X[X.columns[9:15]])
# The coefficients
print('Coefficients: \n', reg.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % metrics.mean_squared_error(Y, y_pred, squared=False))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % metrics.r2_score(Y, y_pred))
# Out:
# Coefficients:
#  [-0.19464131  0.03177826  0.05562416 -0.13901715  0.02118562 -0.01847171]
# Mean squared error: 1.93
# Coefficient of determination: 0.34

# %%
poly = preprocessing.PolynomialFeatures(degree=2)
X_poly=poly.fit_transform(X)

# %%
X_poly.shape
# Out:
# (9982, 153)

# %%
reg = linear_model.Lasso(alpha=0.5, max_iter=100000)
reg.fit(X_poly,Y)
y_pred=reg.predict(X_poly)
# The coefficients
print('Coefficients: \n', reg.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % metrics.mean_squared_error(Y, y_pred, squared=False))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % metrics.r2_score(Y, y_pred))
# Out:
# Coefficients:
#  [ 0.00000000e+00 -1.75190527e-02 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -0.00000000e+00  4.29376694e-03 -0.00000000e+00  0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  1.91609160e-02  4.35537877e-03
#   0.00000000e+00  8.49431859e-06 -4.95934659e-04  7.12152127e-05
#  -5.66644673e-04 -7.98327263e-05  9.41074116e-04  1.14575948e-04
#   1.00157293e-03  2.21340973e-05 -1.25058484e-04 -4.33552828e-04
#   1.78671041e-04 -0.00000000e+00 -1.13445112e-05  6.33893103e-06
#   3.26577970e-03 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  4.84382412e-03
#  -7.81309616e-04 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00  6.78522130e-04 -1.61609477e-04 -6.42320874e-02
#  -1.81822743e-04  5.43554795e-05 -0.00000000e+00  0.00000000e+00
#   1.49240877e-03  0.00000000e+00 -2.37591137e-05  0.00000000e+00
# ...

# %%
path = './full_solubility_database.csv'
full_df = pd.read_csv(path, sep=",")

# %%
full_df.describe()
X=full_df[full_df.columns[1:643]]

# %%
Y=
# Out:
#             ABC      ABCGG  nAcid  nBase  nAromAtom  nAromBond  nAtom  \
# 0     15.325998  11.908140    1.0    1.0        0.0        0.0   69.0
# 1     10.554231   8.981734    0.0    0.0       10.0       11.0   20.0
# 2      6.473351   6.127583    0.0    0.0        6.0        6.0   14.0
# 3     40.125716  33.290350    2.0    0.0       36.0       36.0   95.0
# 4     25.374964  18.024219    0.0    0.0       12.0       12.0   61.0
# ...         ...        ...    ...    ...        ...        ...    ...
# 9977  13.722758  11.378360    0.0    1.0        6.0        6.0   43.0
# 9978  25.416672  21.303532    0.0    1.0        6.0        6.0   56.0
# 9979   8.134854   7.770338    0.0    0.0        6.0        6.0   25.0
# 9980  24.165701  19.978681    0.0    1.0       12.0       12.0   71.0
# 9981  17.872588  14.857897    0.0    0.0       16.0       17.0   39.0
#
#       nHeavyAtom  nSpiro  nBridgehead  ...     SRW09      SRW10     TSRW10  \
# ...

# %%
full_df["logS"]=logS

# %%
Y=full_df.logS

# %%
Y
# Out:
# 0      -3.616127
# 1      -3.254767
# 2      -2.177078
# 3      -3.924409
# 4      -4.662065
#           ...
# 9977   -3.010000
# 9978   -2.930000
# 9979   -2.190000
# 9980   -3.980000
# 9981   -4.780000
# Name: logS, Length: 9982, dtype: float64

# %%
reg = linear_model.Lasso(alpha=0.1, tol=0.1)
reg.fit(X,Y)
y_pred=reg.predict(X)
# The coefficients
print('Coefficients: \n', reg.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % metrics.mean_squared_error(Y, y_pred, squared=False))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % metrics.r2_score(Y, y_pred))
# Out:
# Coefficients:
#  [ 0.00000000e+00 -0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00  0.00000000e+00
#  -0.00000000e+00  0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00  0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -0.00000000e+00 -4.72159547e-03
#  -6.78528633e-03 -3.01751464e-03 -0.00000000e+00  3.43059238e-04
#   9.93528812e-04  1.69270192e-04 -9.12150150e-05 -1.52493704e-03
#   1.96052640e-02  3.38700690e-03  8.25801436e-03  2.67283200e-03
#   9.25618657e-07  0.00000000e+00 -5.07856556e-03 -4.26864094e-04
#  -0.00000000e+00 -1.26765102e-04  2.17763917e-04  2.52542369e-04
#  -2.06023724e-04 -1.66290986e-04  1.01672021e-04  2.54238183e-05
#   5.22855635e-05 -7.69484102e-05  1.24024665e-04 -7.43937336e-05
#   4.13925886e-05  2.68766771e-05  9.29825331e-05 -7.01517124e-05
# ...

# %%
def net_train_and_predict(X, Y, X2, alpha, random_state, verbose = False):
    start_time = time.time()

    scaler_x = MaxStdScaler()
    X_train = scaler_x.fit_transform(X_train)
    scaler_y = MaxStdScaler(factor = 15.0)
    y_train = scaler_y.fit_transform(y_train)

    regressor = MLPRegressor(hidden_layer_sizes = (100, 75, 50, 25), activation = 'relu', solver = 'sgd', learning_rate = 'adaptive', alpha = alpha, random_state = random_state)
    regressor.fit(X_train, y_train)
    print(regressor.loss_)

    y_pred = scaler_y.inverse_transform(regressor.predict(scaler_x.transform(X_pred)), copy = False)

    end_time = time.time()

    if verbose:
        print("Deep regressor traning and predicting finished. Time spent = {:.2f}s.".format(end_time - start_time))

    return y_pred
